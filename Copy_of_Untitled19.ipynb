# %% [markdown]
# <a href="https://colab.research.google.com/github/EARLEJAHNAVI/NA/blob/main/Copy_of_Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask

# %%
# !pip install flask-ngrok requests

# %%
from flask import Flask, jsonify, request
from flask_ngrok import run_with_ngrok

# %%
import requests
import logging
from datetime import datetime

# %%
app = Flask(__name__)
run_with_ngrok(app)

# %%
logging.basicConfig(filename='app.log',level=logging.INFO,format='%(asctime)s - %(levelname)s - %(message)s')

# %%
BASE_URL = "https://jsonplaceholder.typicode.com/posts"

# %%
def log_error(message):
  logging.error(message)

# %%
def safe_request(method, url, **kwargs):
  try:
    res = requests.request(method, url, timeout=5, **kwargs)
    res.raise_for_status()
    return res.json()
  except requests.exceptions.RequestException as e:
    log_error(f"Network Error:{e}")
    return None
  except ValueError:
    log_error(f"Invalid JSON from {url}")
    return None

# %%
@app.route('/posts', methods=['GET'])
def get_posts():
  data = safe_reqest('GET', BASE_URL)
  return jsonify(data or {"error": "Failed to fetch posts"}), 200 if data else 500

# %%
@app.route('/posts/<int:post_id>',methods=['GET'])
def get_post(post_id):
  data = safe_request('GET', f"{BASE_URL}/{post_id}")
  return jsonify(data or {"errror": "post not found"}), 200 if data else 404

# %%
@app.route('/posts/<int:post_id', methods=['PUT'])
def update_post(post_id):
  payload = request.json
  data = safe_request('PUT', f"{BASE_URL}/{post_id}", json=payload)
  return jsonify(data or {"error": "Failed to update post"}), 200 if
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-03d25da4a09e> in <cell line: 0>()
# ----> 1 @app.route('/posts/<int:post_id', methods=['PUT'])
#       2 def update_post(post_id):
#       3   payload = request.json
#       4   data = safe_request('PUT', f"{BASE_URL}/{post_id}", json=payload)
#       5   return jsonify(data or {"error": "Failed to update post"}), 200 if data else 500
#
# /usr/local/lib/python3.11/dist-packages/flask/sansio/scaffold.py in decorator(f)
#     360         def decorator(f: T_route) -> T_route:
#     361             endpoint = options.pop("endpoint", None)
# --> 362             self.add_url_rule(rule, endpoint, f, **options)
#     363             return f
#     364
#
# /usr/local/lib/python3.11/dist-packages/flask/sansio/scaffold.py in wrapper_func(self, *args, **kwargs)
# ...
